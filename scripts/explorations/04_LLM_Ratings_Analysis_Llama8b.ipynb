# %%
from utils import *

# %%
# Folder containing the CSVs
folder_path = "../data/06_llm_ratings_2/"

# List all CSV files in the folder
csv_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".csv") and f.startswith("corrected")])

# Read and process each CSV file
dfs = []
for file in csv_files:
    # Read the CSV into a dataframe
    file_to_load = folder_path+file
    df = pd.read_csv(file_to_load)
    
    # Create a new column name for the rating column using the file's name (excluding .csv)
    new_rating_col = ".".join(file.split('.')[:-1])#+ "_rating"
    
    # Rename the 'rating' column to the new name
    df = df.rename(columns={"rating": new_rating_col})
    dfs.append(df)


# Merge all dataframes on the "name" column using an outer join (to keep all rows)
merged_df = reduce(lambda left, right: pd.merge(left, right, on="name", how="outer"), dfs)
merged_df.head()
# Out:
#                name  \
# 0  SUB001_SPEECH001
# 1  SUB002_SPEECH001
# 2  SUB003_SPEECH001
# 3  SUB005_SPEECH001
# 4  SUB005_SPEECH002
#
#    corrected_transcripts_gemini1.5flash_slice#0.01_prompt#1_rating  \
# 0                                                  2
# 1                                                  3
# 2                                                  2
# 3                                                  4
# 4                                                  2
#
#    corrected_transcripts_gemini1.5flash_slice#0.01_prompt#2_rating  \
# 0                                                  2
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  2
#
#    corrected_transcripts_gemini1.5flash_slice#0.01_prompt#3_rating  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#    corrected_transcripts_gemini1.5flash_slice#0.01_prompt#4_rating  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#    corrected_transcripts_gemini1.5flash_slice#0.01_prompt#5_rating  \
# 0                                                  3
# 1                                                  2
# 2                                                  2
# 3                                                  3
# 4                                                  2
#
#    corrected_transcripts_gemini1.5flash_slice#0.05_prompt#1_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gemini1.5flash_slice#0.05_prompt#2_rating  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    corrected_transcripts_gemini1.5flash_slice#0.05_prompt#3_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#    corrected_transcripts_gemini1.5flash_slice#0.05_prompt#4_rating  ...  \
# 0                                                  4                ...
# 1                                                  3                ...
# 2                                                  3                ...
# 3                                                  4                ...
# 4                                                  3                ...
#
#    corrected_transcripts_llama3_8b_slice#0.75_prompt#1_rating  \
# 0                                                  5
# 1                                                  6
# 2                                                  4
# 3                                                  8
# 4                                                  7
#
#    corrected_transcripts_llama3_8b_slice#0.75_prompt#2_rating  \
# 0                                                  7
# 1                                                  6
# 2                                                  2
# 3                                                  6
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#0.75_prompt#3_rating  \
# 0                                                  6
# 1                                                  6
# 2                                                  6
# 3                                                  8
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#0.75_prompt#4_rating  \
# 0                                                  7
# 1                                                  8
# 2                                                  3
# 3                                                  8
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#0.75_prompt#5_rating  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  8
# 4                                                  7
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#1_rating  \
# 0                                                  7
# 1                                                  7
# 2                                                  6
# 3                                                  9
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#2_rating  \
# 0                                                  6
# 1                                                  8
# 2                                                  7
# 3                                                  8
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#3_rating  \
# 0                                                  8
# 1                                                  8
# 2                                                  7
# 3                                                  8
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#4_rating  \
# 0                                                  6
# 1                                                  8
# 2                                                  3
# 3                                                  8
# 4                                                  8
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#5_rating
# 0                                                  8
# 1                                                  8
# 2                                                  6
# 3                                                  8
# 4                                                  6
#
# [5 rows x 136 columns]

# %%
# Select only columns that contain "slice#0.2" # AND/or "gemini"
selected_columns = [col for col in merged_df.columns if "slice#0.2" in col ]#and "gemini" in col]
selected_columns2 = selected_columns.copy()
selected_columns2.append('name')

# Create a new DataFrame with only the selected columns
df_filtered = merged_df[selected_columns]
df_filtered.head()

df_filtered2 = merged_df[selected_columns2]
df_filtered2.to_csv('../data/05_llm_ratings/llm_ratings_combined0.2.csv')
df_filtered2.head()
# Out:
#    corrected_transcripts_gemini1.5flash_slice#0.2_prompt#1_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gemini1.5flash_slice#0.2_prompt#2_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    corrected_transcripts_gemini1.5flash_slice#0.2_prompt#3_rating  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gemini1.5flash_slice#0.2_prompt#4_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gemini1.5flash_slice#0.2_prompt#5_rating  \
# 0                                                  6
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gpt4omini_slice#0.2_prompt#1_rating  \
# 0                                                  5
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    corrected_transcripts_gpt4omini_slice#0.2_prompt#2_rating  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    corrected_transcripts_gpt4omini_slice#0.2_prompt#3_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    corrected_transcripts_gpt4omini_slice#0.2_prompt#4_rating  \
# 0                                                  5
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    corrected_transcripts_gpt4omini_slice#0.2_prompt#5_rating  \
# 0                                                  5
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_llama3_8b_slice#0.2_prompt#1_rating  \
# 0                                                  6
# 1                                                  6
# 2                                                  6
# 3                                                  4
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#0.2_prompt#2_rating  \
# 0                                                  6
# 1                                                  6
# 2                                                  3
# 3                                                  6
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#0.2_prompt#3_rating  \
# 0                                                  7
# 1                                                  7
# 2                                                  6
# 3                                                  6
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#0.2_prompt#4_rating  \
# 0                                                  6
# 1                                                  6
# 2                                                  6
# 3                                                  4
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#0.2_prompt#5_rating              name
# 0                                                  6          SUB001_SPEECH001
# 1                                                  8          SUB002_SPEECH001
# 2                                                  8          SUB003_SPEECH001
# 3                                                  6          SUB005_SPEECH001
# 4                                                  6          SUB005_SPEECH002

# %%
# Select only columns that contain "slice#0.2" # AND/or "gemini"
selected_columns = [col for col in merged_df.columns if "slice#1.0" in col ]#and "gemini" in col]
selected_columns2 = selected_columns.copy()
selected_columns2.append('name')

# Create a new DataFrame with only the selected columns
df_filtered = merged_df[selected_columns]
df_filtered.head()
# Out:
#    corrected_transcripts_gemini1.5flash_slice#1.0_prompt#1_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gemini1.5flash_slice#1.0_prompt#2_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    corrected_transcripts_gemini1.5flash_slice#1.0_prompt#3_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gemini1.5flash_slice#1.0_prompt#4_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gemini1.5flash_slice#1.0_prompt#5_rating  \
# 0                                                  6
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    corrected_transcripts_gpt4omini_slice#1.0_prompt#1_rating  \
# 0                                                  4
# 1                                                  5
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#    corrected_transcripts_gpt4omini_slice#1.0_prompt#2_rating  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    corrected_transcripts_gpt4omini_slice#1.0_prompt#3_rating  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    corrected_transcripts_gpt4omini_slice#1.0_prompt#4_rating  \
# 0                                                  5
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    corrected_transcripts_gpt4omini_slice#1.0_prompt#5_rating  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#1_rating  \
# 0                                                  7
# 1                                                  7
# 2                                                  6
# 3                                                  9
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#2_rating  \
# 0                                                  6
# 1                                                  8
# 2                                                  7
# 3                                                  8
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#3_rating  \
# 0                                                  8
# 1                                                  8
# 2                                                  7
# 3                                                  8
# 4                                                  6
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#4_rating  \
# 0                                                  6
# 1                                                  8
# 2                                                  3
# 3                                                  8
# 4                                                  8
#
#    corrected_transcripts_llama3_8b_slice#1.0_prompt#5_rating
# 0                                                  8
# 1                                                  8
# 2                                                  6
# 3                                                  8
# 4                                                  6

# %%
selected_columns2
# Out:
# ['corrected_transcripts_gemini1.5flash_slice#1.0_prompt#1_rating',
#  'corrected_transcripts_gemini1.5flash_slice#1.0_prompt#2_rating',
#  'corrected_transcripts_gemini1.5flash_slice#1.0_prompt#3_rating',
#  'corrected_transcripts_gemini1.5flash_slice#1.0_prompt#4_rating',
#  'corrected_transcripts_gemini1.5flash_slice#1.0_prompt#5_rating',
#  'corrected_transcripts_gpt4omini_slice#1.0_prompt#1_rating',
#  'corrected_transcripts_gpt4omini_slice#1.0_prompt#2_rating',
#  'corrected_transcripts_gpt4omini_slice#1.0_prompt#3_rating',
#  'corrected_transcripts_gpt4omini_slice#1.0_prompt#4_rating',
#  'corrected_transcripts_gpt4omini_slice#1.0_prompt#5_rating',
#  'corrected_transcripts_llama3_8b_slice#1.0_prompt#1_rating',
#  'corrected_transcripts_llama3_8b_slice#1.0_prompt#2_rating',
#  'corrected_transcripts_llama3_8b_slice#1.0_prompt#3_rating',
#  'corrected_transcripts_llama3_8b_slice#1.0_prompt#4_rating',
#  'corrected_transcripts_llama3_8b_slice#1.0_prompt#5_rating',
#  'name']

# %%
df_filtered2 = merged_df[selected_columns2]
df_filtered2.to_csv('../data/05_llm_ratings/llm_ratings_combined_gemini15flash_gpt4omini_llama38b_1.0.csv')
df_filtered2.head()
df_filtered2['Mean_Score'] = df_filtered2.select_dtypes(include=['number']).mean(axis=1)
df_filtered2
# Out:
# /var/folders/n8/p7l_d2b909q_62kkjh81kbpr0000gq/T/ipykernel_59925/874557820.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered2['Mean_Score'] = df_filtered2.select_dtypes(include=['number']).mean(axis=1)
#      corrected_transcripts_gemini1.5flash_slice#1.0_prompt#1_rating  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 123                                                  6
# 124                                                  7
# 125                                                  6
# 126                                                  4
# 127                                                  4
#
#      corrected_transcripts_gemini1.5flash_slice#1.0_prompt#2_rating  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 123                                                  6
# 124                                                  6
# 125                                                  6
# 126                                                  4
# 127                                                  4
#
#      corrected_transcripts_gemini1.5flash_slice#1.0_prompt#3_rating  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 123                                                  5
# 124                                                  6
# 125                                                  6
# 126                                                  4
# 127                                                  4
#
#      corrected_transcripts_gemini1.5flash_slice#1.0_prompt#4_rating  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 123                                                  4
# 124                                                  6
# 125                                                  6
# 126                                                  4
# 127                                                  4
#
#      corrected_transcripts_gemini1.5flash_slice#1.0_prompt#5_rating  \
# 0                                                    6
# 1                                                    4
# 2                                                    4
# 3                                                    5
# 4                                                    4
# ..                                                 ...
# 123                                                  6
# 124                                                  7
# 125                                                  7
# 126                                                  4
# 127                                                  4
#
#      corrected_transcripts_gpt4omini_slice#1.0_prompt#1_rating  \
# 0                                                    4
# 1                                                    5
# 2                                                    3
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 123                                                  5
# 124                                                  7
# 125                                                  6
# 126                                                  5
# 127                                                  5
#
#      corrected_transcripts_gpt4omini_slice#1.0_prompt#2_rating  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 123                                                  6
# 124                                                  7
# 125                                                  6
# 126                                                  3
# 127                                                  4
#
#      corrected_transcripts_gpt4omini_slice#1.0_prompt#3_rating  \
# 0                                                    5
# 1                                                    4
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 123                                                  6
# 124                                                  7
# 125                                                  7
# 126                                                  3
# 127                                                  4
#
#      corrected_transcripts_gpt4omini_slice#1.0_prompt#4_rating  \
# 0                                                    5
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 123                                                  6
# 124                                                  7
# 125                                                  6
# 126                                                  4
# 127                                                  4
#
#      corrected_transcripts_gpt4omini_slice#1.0_prompt#5_rating  \
# 0                                                    5
# 1                                                    5
# 2                                                    4
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 123                                                  6
# 124                                                  8
# 125                                                  8
# 126                                                  4
# 127                                                  5
#
#      corrected_transcripts_llama3_8b_slice#1.0_prompt#1_rating  \
# 0                                                    7
# 1                                                    7
# 2                                                    6
# 3                                                    9
# 4                                                    6
# ..                                                 ...
# 123                                                  9
# 124                                                  8
# 125                                                  8
# 126                                                  7
# 127                                                  6
#
#      corrected_transcripts_llama3_8b_slice#1.0_prompt#2_rating  \
# 0                                                    6
# 1                                                    8
# 2                                                    7
# 3                                                    8
# 4                                                    6
# ..                                                 ...
# 123                                                  8
# 124                                                  8
# 125                                                  8
# 126                                                  8
# 127                                                  8
#
#      corrected_transcripts_llama3_8b_slice#1.0_prompt#3_rating  \
# 0                                                    8
# 1                                                    8
# 2                                                    7
# 3                                                    8
# 4                                                    6
# ..                                                 ...
# 123                                                  8
# 124                                                  9
# 125                                                  8
# 126                                                  6
# 127                                                  8
#
#      corrected_transcripts_llama3_8b_slice#1.0_prompt#4_rating  \
# 0                                                    6
# 1                                                    8
# 2                                                    3
# 3                                                    8
# 4                                                    8
# ..                                                 ...
# 123                                                  8
# 124                                                  8
# 125                                                  8
# 126                                                  7
# 127                                                  7
#
#      corrected_transcripts_llama3_8b_slice#1.0_prompt#5_rating  \
# 0                                                    8
# 1                                                    8
# 2                                                    6
# 3                                                    8
# 4                                                    6
# ..                                                 ...
# 123                                                  9
# 124                                                  8
# 125                                                  7
# 126                                                  7
# 127                                                  6
#
#                  name  Mean_Score
# 0    SUB001_SPEECH001    5.333333
# 1    SUB002_SPEECH001    5.333333
# 2    SUB003_SPEECH001    4.466667
# 3    SUB005_SPEECH001    5.266667
# 4    SUB005_SPEECH002    4.533333
# ..                ...         ...
# 123  SUB078_SPEECH002    6.533333
# 124  SUB079_SPEECH001    7.266667
# 125  SUB079_SPEECH002    6.866667
# 126  SUB080_SPEECH001    4.933333
# 127  SUB080_SPEECH002    5.133333
#
# [128 rows x 17 columns]

# %%
df_filtered3 = df_filtered2[['name', 'Mean_Score']]
df_filtered3 = df_filtered3.rename(columns={'name': 'Speech'})
df_filtered3.to_csv('../data/05_llm_ratings/averaged_llm_ratings_gemini15flash_gpt4omini_llama38b_1.0.csv')

# %%
ratings_matrix_llm = df_filtered.T.iloc[:, :]
icc_value_llm = compute_icc(ratings_matrix_llm)
icc_value_llm
# Out:
# 0.9955327008602878

# %%
plt.imshow(ratings_matrix_llm.T.corr(), vmin=-1, vmax=1, cmap='seismic')
plt.colorbar()

# %%
# Select only the numeric columns (excluding "name")
numeric_columns = [col for col in df_filtered2.columns if col != "name"]

# Compute the mean across all numeric columns
df["Mean_Rating"] = df_filtered2[numeric_columns].mean(axis=1)
#df.head()
# Create a new DataFrame with "name" and the computed mean
df_result = df[["name", "Mean_Rating"]]
df_result = df.rename(columns={"name": "Speech", "Mean_Rating": "Mean_Score"})

df_result.to_csv('../data/averaged_llm_ratings_gemini15flash_gpt4omini_llama38b_slice0.2.csv')
